# %% [markdown]
# ## Load outer libraries

# %%
import pandas as pd
import numpy as np
from __future__ import division
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
sns.set(style="darkgrid")

# %matplotlib inline

# %% [markdown]
# ## Load my libraries

# %%
from spikeHelper.experiments import expAllRats
from spikeHelper.dataOrganization import singleRatResults, trialToXyT, getX
from spikeHelper.visuals import evolutionPlot

# %%
#results = expAllRats()
#pickle.dump(results, open('Results/nome','wb'))
results = pickle.load( open('Results/resultsRaw_50ms_1sPlus_1308','rb') )

# %% [markdown]
# Alinhar pela direita, observar ERP atividade motora, desvio etc

# %% [markdown]
# Classificador sem atividade motora

# %% [markdown]
# Desempenho por n. neuronios

# %% [markdown]
# Reduzir numero de trials de treino. 40?30?

# %% [markdown]
# 1 a 1.5 vertical
# 2 a 2.5 horizontal

# %% [markdown]
# Novo pente fino sobre qualidade neuronal

# %% [markdown]
# # Resultado médio para cada aspecto

# %%
results.iloc[:4,:8].applymap(lambda x: np.nan_to_num(x).mean())
# Out:
#         Late corr  Late kappa  Early corr  Early kappa  Cross late train corr  \
# rat 7    0.756022    0.055789    0.795624     0.053316               0.472143
# rat 8    0.861620    0.088105    0.852122     0.085842               0.761353
# rat 9    0.833504    0.073053    0.815353     0.093368               0.568110
# rat 10   0.589714    0.057474    0.658195     0.076211               0.305042
#
#         Cross late train kappa  Cross early train corr  \
# rat 7                 0.277458                0.535309
# rat 8                 0.415367                0.773199
# rat 9                 0.327318                0.623983
# rat 10                0.222468                0.257308
#
#         Cross early train kappa
# rat 7                  0.264087
# rat 8                  0.414187
# rat 9                  0.310739
# rat 10                 0.186851

# %% [markdown]
# ### Desvio padrão

# %%
results.iloc[:4,:8].apply(lambda x: x.apply(lambda x: np.nan_to_num(x).std()))
# Out:
#         Late corr  Late kappa  Early corr  Early kappa  Cross late train corr  \
# rat 7    0.230358    0.040782    0.139747     0.035883               0.018868
# rat 8    0.071559    0.057696    0.116229     0.054362               0.003671
# rat 9    0.128927    0.044331    0.206734     0.072259               0.018651
# rat 10   0.391309    0.047296    0.383156     0.061182               0.028717
#
#         Cross late train kappa  Cross early train corr  \
# rat 7                 0.010292                0.034752
# rat 8                 0.002707                0.004690
# rat 9                 0.012458                0.009602
# rat 10                0.015649                0.017302
#
#         Cross early train kappa
# rat 7                  0.019912
# rat 8                  0.003130
# rat 9                  0.005281
# rat 10                 0.009904

# %% [markdown]
# # Evolução do desempenho dos classificadores treinados nas últimas tentativas

# %%
results.iloc[:4,-3:-1] = results.iloc[:4,-3:-1].apply(lambda x: x.apply(lambda y: y.apply(np.nan_to_num)))

# %%
evolutionPlot(results)
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ---

# %%
from sklearn.svm import SVC
from spikeHelper.experiments import *

# %%
clf=SVC()
n_splits = 3
results = {}

ypred, ytrue = eachSame(clf, data[data['end']], n_splits)
results['late'] = {}
results['late']['corr'] = np.array([[st.pearsonr(ypred[ti, clfi, :], ytrue[ti,:])[0] for ti in range(ypred.shape[0])] for clfi in range(ypred.shape[1])])
results['late']['kappa'] = np.array([[cohen_kappa_score(ypred[ti, clfi, :], ytrue[ti,:]) for ti in range(ypred.shape[0])] for clfi in range(ypred.shape[1])])


ypred, ytrue = eachSame(clf, data[data['beg']], n_splits)
results['early'] = {}
results['early']['corr'] = np.array([[st.pearsonr(ypred[ti, clfi, :], ytrue[ti,:])[0] for ti in range(ypred.shape[0])] for clfi in range(ypred.shape[1])])
results['early']['kappa'] = np.array([[cohen_kappa_score(ypred[ti, clfi, :], ytrue[ti,:]) for ti in range(ypred.shape[0])] for clfi in range(ypred.shape[1])])

# %%
np.array([[st.pearsonr(ypred[ti, clfi, :], ytrue[ti,:])[0] for ti in range(ypred.shape[0])] for clfi in range(ypred.shape[1])])
