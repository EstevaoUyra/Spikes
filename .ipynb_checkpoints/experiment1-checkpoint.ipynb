# %% [markdown]
# ## Load outer libraries

# %%
import pandas as pd
import numpy as np
from __future__ import division
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
sns.set(style="darkgrid")

# %matplotlib inline

# %% [markdown]
# ## Load my libraries

# %%
from spikeHelper.experiments import expAllRats
from spikeHelper.dataOrganization import singleRatResults, trialToXyT, getX
from spikeHelper.visuals import evolutionPlot

# %%
#results = expAllRats()
results = pickle.load(open('noGridResults.pickle','rb'))

# %% [markdown]
# # Resultado médio para cada aspecto

# %%
results.iloc[[0,1,3],:8].apply(lambda x: x.apply(np.mean))
# Out:
#         Late corr  Late kappa  Early corr  Early kappa  Cross late train corr  \
# rat 7    0.771571    0.110526    0.779127     0.111789               0.571404
# rat 8    0.832430    0.129579    0.866232     0.135895               0.823932
# rat 10   0.718077    0.110947    0.703067     0.103316               0.645090
#
#         Cross late train kappa  Cross early train corr  \
# rat 7                 0.378336                0.716550
# rat 8                 0.593373                0.807160
# rat 10                0.454366                0.631881
#
#         Cross early train kappa
# rat 7                  0.491114
# rat 8                  0.584080
# rat 10                 0.450395

# %% [markdown]
# ### Desvio padrão

# %%
results.iloc[[0,1,3],:8].apply(lambda x: x.apply(np.std))
# Out:
#         Late corr  Late kappa  Early corr  Early kappa  Cross late train corr  \
# rat 7    0.190877    0.045091    0.189794     0.045660               0.006334
# rat 8    0.152296    0.053843    0.117341     0.057782               0.003865
# rat 10   0.250998    0.053579    0.254058     0.051289               0.007042
#
#         Cross late train kappa  Cross early train corr  \
# rat 7                 0.005996                0.005335
# rat 8                 0.003383                0.002499
# rat 10                0.007756                0.005243
#
#         Cross early train kappa
# rat 7                  0.006023
# rat 8                  0.004876
# rat 10                 0.004784

# %% [markdown]
# # Evolução do desempenho

# %%
evolutionPlot(results)
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
