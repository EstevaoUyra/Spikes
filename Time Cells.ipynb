# %%
from spikeHelper.visuals import heatAct
from spikeHelper.dataOrganization import trialToXyT
import pickle
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Rato 7

# %%
rat = 7
data = pickle.load(open('Data/50ms_r'+str(rat)+'_1300msPlus1s.pickle','rb'))
#data = pickle.load(open('Data/50ms_r7_3000to3500.pickle','rb'))
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 29
# Number of times 20
# Number of trials 955

# %%
plt.subplot(1,2,1)
heatAct(trialToXyT(data[:,:,:200]))
plt.subplot(1,2,2)
heatAct(trialToXyT(data[:,:,-45:]))

# %% [markdown]
# # Rato 8

# %%
rat = 8
data = pickle.load(open('Data/50ms_r'+str(rat)+'_1300msPlus1s.pickle','rb'))
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 37
# Number of times 20
# Number of trials 671

# %%
plt.subplot(1,2,1)
heatAct(trialToXyT(data[:,:,:200]))
plt.subplot(1,2,2)
heatAct(trialToXyT(data[:,:,-200:]))

# %% [markdown]
# # Rato 9

# %%
rat = 9
data = pickle.load(open('Data/50ms_r'+str(rat)+'_1300msPlus1s.pickle','rb'))
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 29
# Number of times 20
# Number of trials 683

# %%
plt.subplot(1,2,1)
heatAct(trialToXyT(data[:,:,:90]))
plt.subplot(1,2,2)
heatAct(trialToXyT(data[:,:,-90:]))
# Out:
# /home/tevo/Documents/UFABC/Spikes/spikeHelper/dataOrganization.py:38: RuntimeWarning: invalid value encountered in true_divide
#   return np.array([k[i,:]/(k.max(axis=1)[i]) for i in range(k.shape[0])])

# %% [markdown]
# # Rato 10

# %%
ls Data/
# Out:
# 50ms_r10_1000to1500.pickle    gcells_R7_2.mat
# 50ms_r10_1300msPlus1s.pickle  gcells_R7.mat
# 50ms_r10_2000to2500.pickle    gcells_R8_2.mat
# 50ms_r10_3000to3500.pickle    gcells_R8.mat
# 50ms_r7_1000to1500.pickle     gcells_R9_2.mat
# 50ms_r7_1300msPlus1s.pickle   gcells_R9.mat
# 50ms_r7_2000to2500.pickle     goodCellsR10_withBaseDiff
# 50ms_r7_3000to3500.pickle     goodCellsR7_withBaseDiff
# 50ms_r8_1000msPlus.pickle     goodCellsR8_withBaseDiff
# 50ms_r8_1000to1500.pickle     goodCellsR9_withBaseDiff
# 50ms_r8_1300msPlus1s.pickle   r10_filtered_epoch_gabi.pickle
# 50ms_r8_2000to2500.pickle     r7_filtered_epoch_fr1_isi5.pickle
# 50ms_r8_3000to3500.pickle     r7_filtered_epoch_gabi.pickle
# 50ms_r9_1000msPlus.pickle     r8_filtered_epoch_fr1_isi5.pickle
# 50ms_r9_1000to1500.pickle     r8_filtered_epoch_gabi.pickle
# 50ms_r9_1300msPlus1s.pickle   r9_filtered_epoch_fr1_isi5.pickle
# 50ms_r9_2000to2500.pickle     r9_filtered_epoch_gabi.pickle
# ...

# %%
rat = 10
data = pickle.load(open('Data/50ms_r'+str(rat)+'_1300msPlus1s.pickle','rb'))
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 65
# Number of times 20
# Number of trials 1429

# %%
plt.subplot(1,2,1)
heatAct(trialToXyT(data[:,:,:200]))
plt.subplot(1,2,2)
heatAct(trialToXyT(data[:,:,-200:]))
