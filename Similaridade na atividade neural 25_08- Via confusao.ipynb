# %% [markdown]
# # Similaridade na atividade neural dos diferentes tempos
# ### Medida através da matriz de confusão
# - Foram selecionadas as tentativas com $\textbf{duração > 1300ms}$
# - A atividade foi convolucionada com kernel gaussiano de $\sigma_{kernel}=100$ms.
# - Os últimos 300ms das tentativas foram descartados, para diminuir a influência da ação motora.
# - A atividade foi dividida em 20 bins de 50ms
#
# ### As medidas
# - Para cada um dos instantes i = 1, 2,...,20, o vetor médio das atividades foi utilizado como template $\tau_i$ para comparação. O template sempre foi feito deixando de fora toda uma trial, e testado nas tentativas daquela trial.
# - Para cada instante j, cada tentativa $\mathscr{t} \in \mathscr{T}$(o subconjunto de tentativas) foi comparada aos templates, e classificada como pertencente ao tempo cujo template era mais similar a ela.
# - As medidas de distância utilizadas foram a euclideana, $$D_e(\vec{u},\vec{v}) = ||\vec{u}-\vec{v}||$$ e a de mahalanobis $$ D_m(\vec{u},\vec{v}) = \sqrt{(\vec{u}-\vec{v})^T\textbf{S}^{-1}(\vec{u}-\vec{v})}$$ sendo $\textbf{S}^{-1}$ a matriz de precisão, ou o inverso da matriz de covariância calculada sobre as tentativas $\mathscr{T}$
#
# # RETIRAR TRIAL INTEIRA

# %%
import pickle
from spikeHelper.visuals import compareSimilarities
from spikeHelper.dataOrganization import XyTfromEpoch
# %matplotlib inline
sigma=100

# %% [markdown]
# ---

# %% [markdown]
# ## Rato 7

# %%
rat = 7
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma100.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36],verbose=True)[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Minimum size not restricted. Using all up from  12
# Maximum size not restricted. Using all up to  222
# Number of neurons 29
# Number of times 20
# Number of trials 753

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=50,normalize=True,transform=True)

# %% [markdown]
# ## Rato 8

# %%
rat = 8
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma100.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36])[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 37
# Number of times 20
# Number of trials 537

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=50,normalize=True,transform=True)

# %% [markdown]
# ## Rato 9

# %%
rat = 9
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma100.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36])[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 29
# Number of times 20
# Number of trials 566

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=50,transform=True)

# %% [markdown]
# ## Rato 10

# %%
rat = 10
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma100.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36])[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 65
# Number of times 20
# Number of trials 1206

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=50,transform=True)

# %% [markdown]
# ---

# %% [markdown]
# # Aumento do número de tentativas em uso
# ### Imagens idênticas às anteriores, exceto pelo número de tentativas sendo utilizadas nos gráficos parciais

# %% [markdown]
# ## Rato 7

# %%
rat = 7
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma'+str(sigma)+'.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36])[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 29
# Number of times 20
# Number of trials 753

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=200)

# %% [markdown]
# ## Rato 8

# %%
rat = 8
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma'+str(sigma)+'.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36])[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 37
# Number of times 20
# Number of trials 537

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=200)

# %% [markdown]
# ## Rato 9

# %%
rat = 9
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma'+str(sigma)+'.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,30],minBins=36)
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 29
# Number of times 20
# Number of trials 566

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=200)

# %% [markdown]
# ## Rato 10

# %%
rat = 10
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma'+str(sigma)+'.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,30],minBins=36)
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 65
# Number of times 20
# Number of trials 1206

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=200)

# %% [markdown]
# # Sem normalização das linhas

# %% [markdown]
# ## Rato 7

# %%
rat = 7
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma'+str(sigma)+'.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36])[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 29
# Number of times 20
# Number of trials 753

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=50,normalize=False)

# %% [markdown]
# ## Rato 8

# %%
rat = 8
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma'+str(sigma)+'.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36])[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 37
# Number of times 20
# Number of trials 537

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=50,normalize=False)

# %% [markdown]
# ## Rato 9

# %%
rat = 9
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma'+str(sigma)+'.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36])[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 29
# Number of times 20
# Number of trials 566

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=50,normalize=False)

# %% [markdown]
# ## Rato 10

# %%
rat = 10
data = pickle.load(open('Data/r'+str(rat)+'_bin50_sigma'+str(sigma)+'.pickle','rb'))
data = XyTfromEpoch(data,getBins=[10,36])[:,:20,:]
print('Number of neurons',data.shape[0])
print('Number of times',data.shape[1])
print('Number of trials',data.shape[2])
# Out:
# Number of neurons 65
# Number of times 20
# Number of trials 1206

# %%
compareSimilarities(data,'Similaridade temporal rato '+str(rat),nTrials=50,normalize=False)
